# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv('./data/mental-heath-in-tech-2016_20161114.csv')
data = np.array([df['What is your age?'],
        df['What is your gender?'],
        df['What country do you live in?'],
        df['What country do you work in?'],
        df['How many employees does your company or organization have?'],
        df['Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?'],
        df['Do you have a family history of mental illness?'],
        df['Have you had a mental health disorder in the past?'],
        df['Do you currently have a mental health disorder?'],
        df['Have you ever sought treatment for a mental health issue from a mental health professional?'],
        df['Do you work remotely?']
       ])

columns= ['age',
         'gender',
         'residence_location',
         'work_location',
         'num_employees',
         'employer_awareness',
         'family_history',
         'past_history',
         'current_state',
         'treatment',
         'remote']
df = pd.DataFrame(data = data)
df = df.T
df.columns = columns
df
# Out:
#      age                 gender        residence_location  \
# 0     39                   Male            United Kingdom
# 1     29                   male  United States of America
# 2     38                  Male             United Kingdom
# 3     43                   male            United Kingdom
# 4     43                 Female  United States of America
# 5     42                   Male            United Kingdom
# 6     30                      M  United States of America
# 7     37                 female  United States of America
# 8     44                 Female  United States of America
# 9     30                   Male  United States of America
# 10    28                   Male  United States of America
# 11    34                   Male  United States of America
# 12    30                 Female  United States of America
# 13    44                   Male                    Canada
# 14    35                   Male  United States of America
# 15    52                      m  United States of America
# 16    32  I identify as female.                    Canada
# 17    34                   Male            United Kingdom
# 18    25                female   United States of America
# 19    31                      M  United States of America
# 20    26                   Male  United States of America
# 21    35                   male  United States of America
# 22    25                   male                   Germany
# 23    33                   Male                    Canada
# 24    38                   Male  United States of America
# 25    42                   male                   Germany
# 26    27                   Male               Netherlands
# 27    35                   male                   Germany
# 28    34                 female            United Kingdom
# 29    32               Bigender            United Kingdom
# ...   ..                    ...                       ...
# 1403  27                   Male                     India
# 1404  29                   Male                    Canada
# 1405  28                   Male                    Poland
# 1406  26      Transgender woman                   Ireland
# 1407  29                   male               Afghanistan
# 1408  34                      m                   Germany
# 1409  36                   Male            United Kingdom
# 1410  38                   Male                   Belgium
# 1411  22                 Female  United States of America
# 1412  24                   male  United States of America
# 1413  24                 female  United States of America
# 1414  36                 female  United States of America
# 1415  24                 Female  United States of America
# 1416  24                   Male  United States of America
# 1417  31                   Male               Netherlands
# 1418  39                      M            United Kingdom
# 1419  41                   male  United States of America
# 1420  29                   Male            United Kingdom
# 1421  37                   male                   Estonia
# 1422  30                   male                    Canada
# 1423  24                   Male                    Canada
# 1424  22                 female                    Canada
# 1425  24                   Male                    Canada
# 1426  26                 Female                    Canada
# 1427  38                 female  United States of America
# 1428  34                Female   United States of America
# 1429  56                   MALE  United States of America
# 1430  52                   Male  United States of America
# 1431  30                 Female  United States of America
# 1432  25             non-binary                    Canada
#
#                  work_location   num_employees employer_awareness  \
# 0               United Kingdom          26-100                 No
# 1     United States of America            6-25                Yes
# 2               United Kingdom            6-25                 No
# 3               United Kingdom             NaN                NaN
# 4     United States of America            6-25                 No
# 5               United Kingdom  More than 1000                 No
# 6     United States of America          26-100                 No
# 7     United States of America  More than 1000                 No
# 8     United States of America          26-100                 No
# 9     United States of America             NaN                NaN
# 10    United States of America          26-100                Yes
# 11    United States of America         100-500                 No
# 12    United States of America         100-500                 No
# 13                      Canada         100-500                Yes
# 14    United States of America         100-500                 No
# 1407            Yes          Yes           Yes         1  Sometimes
# 1408             No           No            No         0  Sometimes
# 1409   I don't know           No           Yes         1     Always
# 1410             No        Maybe           Yes         1      Never
# 1411             No          Yes           Yes         1  Sometimes
# 1412             No           No            No         0  Sometimes
# 1413            Yes          Yes           Yes         1  Sometimes
# 1414            Yes          Yes           Yes         1      Never
# 1415            Yes          Yes           Yes         1      Never
# 1416             No           No            No         0      Never
# 1417            Yes          Yes           Yes         1      Never
# 1418             No          Yes           Yes         0      Never
# 1419            Yes          Yes           Yes         1  Sometimes
# 1420   I don't know        Maybe         Maybe         0     Always
# 1421   I don't know           No            No         0      Never
# 1422             No           No            No         0     Always
# 1423             No           No            No         0  Sometimes
# 1424   I don't know          Yes           Yes         1  Sometimes
# 1425   I don't know        Maybe         Maybe         0  Sometimes
# 1426   I don't know          Yes           Yes         1  Sometimes
# 1427            Yes          Yes           Yes         1     Always
# 1428            Yes           No            No         1  Sometimes
# 1429            Yes           No            No         0  Sometimes
# 1430            Yes          Yes         Maybe         1  Sometimes
# 1431            Yes        Maybe           Yes         0  Sometimes
# 1432   I don't know          Yes           Yes         0  Sometimes
#
# [1433 rows x 11 columns]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 11 columns):
# age                   1433 non-null object
# gender                1430 non-null object
# residence_location    1433 non-null object
# work_location         1433 non-null object
# num_employees         1146 non-null object
# employer_awareness    1146 non-null object
# family_history        1433 non-null object
# past_history          1433 non-null object
# current_state         1433 non-null object
# treatment             1433 non-null object
# remote                1433 non-null object
# dtypes: object(11)
# memory usage: 123.2+ KB
# None

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1433 entries, 0 to 1432
# Data columns (total 11 columns):
# age                   1433 non-null object
# gender                1430 non-null object
# residence_location    1433 non-null object
# work_location         1433 non-null object
# num_employees         1146 non-null object
# employer_awareness    1146 non-null object
# family_history        1433 non-null object
# past_history          1433 non-null object
# current_state         1433 non-null object
# treatment             1433 non-null object
# remote                1433 non-null object
# dtypes: object(11)
# memory usage: 123.2+ KB
#          age gender        residence_location             work_location  \
# count   1433   1430                      1433                      1433
# unique    53     70                        53                        53
# top       30   Male  United States of America  United States of America
# freq      94    610                       840                       851
#
#        num_employees employer_awareness family_history past_history  \
# count           1146               1146           1433         1433
# unique             6                  3              3            3
# top           26-100                 No            Yes          Yes
# freq             292                813            670          736
#
#        current_state  treatment     remote
# count           1433       1433       1433
# unique             3          2          3
# top              Yes          1  Sometimes
# freq             575        839        757

# %%
#According to the dataframe information, there are some missing data in the gender, num_employees and employer_awareness columns since there are 1433 rows 
df.describe()
# Out:
#          age gender        residence_location             work_location  \
# count   1433   1430                      1433                      1433
# unique    53     70                        53                        53
# top       30   Male  United States of America  United States of America
# freq      94    610                       840                       851
#
#        num_employees employer_awareness family_history past_history  \
# count           1146               1146           1433         1433
# unique             6                  3              3            3
# top           26-100                 No            Yes          Yes
# freq             292                813            670          736
#
#        current_state  treatment     remote
# count           1433       1433       1433
# unique             3          2          3
# top              Yes          1  Sometimes
# freq             575        839        757

# %%
data_des = pd.DataFrame()
data_des['Features'] = df.columns
data_des['Description'] = ['age of the worker',
                           'gender of the worker',
                           'the countery where the worker lives',
                           'the country where the worker works',
                           'how many employees works within the workplace where the worker works', 
                           'whether the employer has formally discussed about the mental health of the worker', 
                           'whether the worker has family hisotry of mental disorder', 
                           'whether the worker has experienced mental disorder in the past',
                           'whether the worker is currently having mental disorder',
                           'if the worker has mental disorder experience, whether he/she sought fot treatment from professinals',
                           'whether the worker work remotely']
data_des['Scales'] = [
    'ordinal',
    'nominal',
    'nominal',
    'nominal',
    'interval',
    'nominal',
    'nominal',
    'nominal',
    'nominal',
    'nominal',
    'nominal'
]

data_des['Discrete/Continuous'] = ['discrete'] * 4 + ['continuous'] + ['discrete'] * 6
data_des
#the table below show the description of features. Obviously the data needs some kind of clean up to improve the data quality.
# Out:
#               Features                                        Description  \
# 0                  age                                  age of the worker
# 1               gender                               gender of the worker
# 2   residence_location                the countery where the worker lives
# 3        work_location                 the country where the worker works
# 4        num_employees  how many employees works within the workplace ...
# 5   employer_awareness  whether the employer has formally discussed ab...
# 6       family_history  whether the worker has family hisotry of menta...
# 7         past_history  whether the worker has experienced mental diso...
# 8        current_state  whether the worker is currently having mental ...
# 9            treatment  if the worker has mental disorder experience, ...
# 10              remote                   whether the worker work remotely
#
#       Scales Discrete/Continuous
# 0    ordinal            discrete
# 1    nominal            discrete
# 2    nominal            discrete
# 3    nominal            discrete
# 4   interval          continuous
# 5    nominal            discrete
# 6    nominal            discrete
# 7    nominal            discrete
# 8    nominal            discrete
# 9    nominal            discrete
# 10   nominal            discrete

# %%
# lets check for any wonky entries in age
df[df.age.apply(lambda x: type(x)!=np.int64)]
# casting as an int
df.age = df.age.astype(np.int64)
df.drop(df[(df.age<16) | (df.age > 65)].index, inplace=True)
#gender
df.gender.replace(to_replace=['Male', 'M', 'male', 'm'], value='Male', inplace=True)
df.gender.replace(to_replace=['Female', 'F', 'female', 'f'], value='Female', inplace=True)
df = df[df.gender.isin(['Male','Female'])]
#number of employees
df.dropna(subset=['num_employees'], inplace=True) #deletes the self-employeed workers.
#treatment
df.treatment = df.treatment.astype(bool)
df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1065 entries, 0 to 1431
# Data columns (total 11 columns):
# age                   1065 non-null int64
# gender                1065 non-null object
# residence_location    1065 non-null object
# work_location         1065 non-null object
# num_employees         1065 non-null object
# employer_awareness    1065 non-null object
# family_history        1065 non-null object
# past_history          1065 non-null object
# current_state         1065 non-null object
# treatment             1065 non-null bool
# remote                1065 non-null object
# dtypes: bool(1), int64(1), object(9)
# memory usage: 92.6+ KB

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore', DeprecationWarning)

# %%
df.groupby('past_history').count()
# Out:
#               age  gender  residence_location  work_location  num_employees  \
# past_history
# Maybe         175     175                 175            175            175
# No            365     365                 365            365            365
# Yes           525     525                 525            525            525
#
#               employer_awareness  family_history  current_state  treatment  \
# past_history
# Maybe                        175             175            175        175
# No                           365             365            365        365
# Yes                          525             525            525        525
#
#               remote
# past_history
# Maybe            175
# No               365
# Yes              525

# %%
labels = ['with past history','without past history','maybe']
sizes = [525, 365, 175]
explode = (0.1,0,0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df.groupby('current_state').count()
# Out:
#                age  gender  residence_location  work_location  num_employees  \
# current_state
# Maybe          241     241                 241            241            241
# No             422     422                 422            422            422
# Yes            402     402                 402            402            402
#
#                employer_awareness  family_history  past_history  treatment  \
# current_state
# Maybe                         241             241           241        241
# No                            422             422           422        422
# Yes                           402             402           402        402
#
#                remote
# current_state
# Maybe             241
# No                422
# Yes               402

# %%
labels = ['Maybe ','currently not experiencing','currently experiencing']
sizes = [241, 422, 402]
explode = (0,0,0.1)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
df.current_state.replace(to_replace = ['Yes','No','Maybe'],
                       value = [1,0,2],
                       inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-b992f286d66f> in <module>()
#       1 df.current_state.replace(to_replace = ['Yes','No','Maybe'],
#       2                        value = [1,0,2],
# ----> 3                        inplace = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    3772                                                        dest_list=value,
#    3773                                                        inplace=inplace,
# -> 3774                                                        regex=regex)
#    3775
#    3776                 else:  # [NA, ''] -> 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in replace_list(self, src_list, dest_list, inplace, regex, mgr)
#    3257             return block, val
#    3258
# -> 3259         masks = [comp(s) for i, s in enumerate(src_list)]
#    3260
#    3261         result_blocks = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    3257             return block, val
#    3258
# -> 3259         masks = [comp(s) for i, s in enumerate(src_list)]
#    3260
#    3261         result_blocks = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in comp(s)
#    3245             if isnull(s):
#    3246                 return isnull(values)
# -> 3247             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3248
#    3249         def _cast_scalar(block, scalar):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _maybe_compare(a, b, op)
#    4617             type_names[1] = 'ndarray(dtype=%s)' % b.dtype
#    4618
# -> 4619         raise TypeError("Cannot compare types %r and %r" % tuple(type_names))
#    4620     return result
#    4621
#
# TypeError: Cannot compare types 'ndarray(dtype=int64)' and 'str'

# %%
df.past_history.replace(to_replace = ['Yes','No','Maybe'],
                       value = [1,0,2],
                       inplace = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-3c0c2e35b0a3> in <module>()
#       1 df.past_history.replace(to_replace = ['Yes','No','Maybe'],
#       2                        value = [1,0,2],
# ----> 3                        inplace = True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method, axis)
#    3772                                                        dest_list=value,
#    3773                                                        inplace=inplace,
# -> 3774                                                        regex=regex)
#    3775
#    3776                 else:  # [NA, ''] -> 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in replace_list(self, src_list, dest_list, inplace, regex, mgr)
#    3257             return block, val
#    3258
# -> 3259         masks = [comp(s) for i, s in enumerate(src_list)]
#    3260
#    3261         result_blocks = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in <listcomp>(.0)
#    3257             return block, val
#    3258
# -> 3259         masks = [comp(s) for i, s in enumerate(src_list)]
#    3260
#    3261         result_blocks = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in comp(s)
#    3245             if isnull(s):
#    3246                 return isnull(values)
# -> 3247             return _maybe_compare(values, getattr(s, 'asm8', s), operator.eq)
#    3248
#    3249         def _cast_scalar(block, scalar):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _maybe_compare(a, b, op)
#    4617             type_names[1] = 'ndarray(dtype=%s)' % b.dtype
#    4618
# -> 4619         raise TypeError("Cannot compare types %r and %r" % tuple(type_names))
#    4620     return result
#    4621
#
# TypeError: Cannot compare types 'ndarray(dtype=int64)' and 'str'

# %%
df
# Out:
#       age  gender        residence_location             work_location  \
# 0      39    Male            United Kingdom            United Kingdom
# 1      29    Male  United States of America  United States of America
# 4      43  Female  United States of America  United States of America
# 5      42    Male            United Kingdom            United Kingdom
# 6      30    Male  United States of America  United States of America
# 7      37  Female  United States of America  United States of America
# 8      44  Female  United States of America  United States of America
# 10     28    Male  United States of America  United States of America
# 11     34    Male  United States of America  United States of America
# 12     30  Female  United States of America  United States of America
# 13     44    Male                    Canada                    Canada
# 14     35    Male  United States of America  United States of America
# 15     52    Male  United States of America  United States of America
# 17     34    Male            United Kingdom            United Kingdom
# 19     31    Male  United States of America  United States of America
# 20     26    Male  United States of America  United States of America
# 21     35    Male  United States of America  United States of America
# 22     25    Male                   Germany                   Germany
# 23     33    Male                    Canada                    Canada
# 25     42    Male                   Germany                   Germany
# 26     27    Male               Netherlands               Netherlands
# 27     35    Male                   Germany                   Germany
# 28     34  Female            United Kingdom            United Kingdom
# 31     30    Male  United States of America  United States of America
# 32     31    Male  United States of America  United States of America
# 34     36    Male            United Kingdom            United Kingdom
# 35     33    Male                   Germany                   Germany
# 36     44    Male  United States of America  United States of America
# 1418          26-100                Yes             No             1
# 1419  More than 1000                Yes            Yes             1
# 1421          26-100                 No   I don't know             0
# 1422          26-100                 No             No             0
# 1423         100-500                Yes             No             0
# 1424         100-500                 No   I don't know             1
# 1425         100-500                Yes   I don't know             2
# 1426         100-500                 No   I don't know             1
# 1427        500-1000                 No            Yes             1
# 1430         100-500                Yes            Yes             1
# 1431         100-500                 No            Yes             2
#
#       current_state  treatment     remote
# 0                 0      False  Sometimes
# 1                 1       True      Never
# 4                 1       True  Sometimes
# 5                 1       True  Sometimes
# 6                 0      False  Sometimes
# 7                 1       True     Always
# 8                 1       True  Sometimes
# 10                1       True      Never
# 11                1       True  Sometimes
# 12                1       True     Always
# 13                2      False  Sometimes
# 14                1       True     Always
# 15                1       True  Sometimes
# 17                0      False      Never
# 19                1       True  Sometimes
# 20                0      False  Sometimes
# 21                0      False      Never
# 22                0      False  Sometimes
# 23                0       True  Sometimes
# 25                0      False      Never
# 26                1       True  Sometimes
# 27                2       True      Never
# 28                2       True      Never
# 31                1       True  Sometimes
# 32                2      False      Never
# 34                1      False  Sometimes
# 35                0      False      Never
# 36                1       True     Always
# 37                2      False      Never
# 38                2       True  Sometimes
# ...             ...        ...        ...
# 1394              2       True      Never
# 1397              1       True     Always
# 1398              1       True      Never
# 1399              1       True  Sometimes
# 1400              2       True     Always
# 1401              1      False      Never
# 1402              1      False  Sometimes
# 1403              1       True  Sometimes
# 1405              2       True      Never
# 1407              1       True  Sometimes
# 1409              1       True     Always
# 1410              1       True      Never
# 1411              1       True  Sometimes
# 1412              0      False  Sometimes
# 1413              1       True  Sometimes
# 1414              1       True      Never
# 1415              1       True      Never
# 1416              0      False      Never
# 1417              1       True      Never
# 1418              1      False      Never
# 1419              1       True  Sometimes
# 1421              0      False      Never
# 1422              0      False     Always
# 1423              0      False  Sometimes
# 1424              1       True  Sometimes
# 1425              2      False  Sometimes
# 1426              1       True  Sometimes
# 1427              1       True     Always
# 1430              2       True  Sometimes
# 1431              1      False  Sometimes
#
# [1065 rows x 11 columns]

# %%
#df_has_experience = df[df['current_state'] == 1 or df['past_history'] == 1]

# %%
#treatment
df.groupby('treatment').count()
# Out:
#            age  gender  residence_location  work_location  num_employees  \
# treatment
# False      472     472                 472            472            472
# True       593     593                 593            593            593
#
#            employer_awareness  family_history  past_history  current_state  \
# treatment
# False                     472             472           472            472
# True                      593             593           593            593
#
#            remote
# treatment
# False         472
# True          593

# %%
df.past_history.replace(to_replace = [True,False],
                       value = [1,0],
                       inplace = True)

# %%
labels = ['accept the treatment','do not accept']
sizes = [593,472]
explode = (0.1,0)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
#treatment
df.groupby('employer_awareness').count()
# Out:
#                     age  gender  residence_location  work_location  \
# employer_awareness
# I don't know         97      97                  97             97
# No                  757     757                 757            757
# Yes                 211     211                 211            211
#
#                     num_employees  family_history  past_history  \
# employer_awareness
# I don't know                   97              97            97
# No                            757             757           757
# Yes                           211             211           211
#
#                     current_state  treatment  remote
# employer_awareness
# I don't know                   97         97      97
# No                            757        757     757
# Yes                           211        211     211

# %%
labels = ['i do not know','employer does not care', 'employer cares']
sizes = [97, 757, 211]
explode = (0,0,0.1)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
